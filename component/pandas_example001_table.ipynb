# %%
import pandas as pd


def pandas_config(url_var1):
    """
    :param url_var1:
    :return:
    """
    var1 = pd.read_csv(url_var1)
    return var1


data = pandas_config("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/11-02-2021.csv")

# %%
data
# Out:
#       FIPS Admin2    Province_State  Country_Region          Last_Update  \
# 0      NaN    NaN               NaN     Afghanistan  2021-11-03 06:22:09
# 1      NaN    NaN               NaN         Albania  2021-11-03 06:22:09
# 2      NaN    NaN               NaN         Algeria  2021-11-03 06:22:09
# 3      NaN    NaN               NaN         Andorra  2021-11-03 06:22:09
# 4      NaN    NaN               NaN          Angola  2021-11-03 06:22:09
# ...    ...    ...               ...             ...                  ...
# 4011   NaN    NaN           Unknown         Ukraine  2021-11-03 06:22:09
# 4012   NaN    NaN               NaN           Nauru  2021-11-03 06:22:09
# 4013   NaN    NaN              Niue     New Zealand  2021-11-03 06:22:09
# 4014   NaN    NaN               NaN          Tuvalu  2021-11-03 06:22:09
# 4015   NaN    NaN  Pitcairn Islands  United Kingdom  2021-11-03 06:22:09
#
#            Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# ...
